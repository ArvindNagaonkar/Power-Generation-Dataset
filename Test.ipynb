# %%
import glob
import pandas as pd

# %%
all_files = glob.glob('./CleanCsv/*.csv')

# %%
all_files
# Out:
# ['./CleanCsv/2017-09-01.csv',
#  './CleanCsv/2017-09-02.csv',
#  './CleanCsv/2017-09-03.csv',
#  './CleanCsv/2017-09-04.csv',
#  './CleanCsv/2017-09-05.csv',
#  './CleanCsv/2017-09-06.csv',
#  './CleanCsv/2017-09-07.csv',
#  './CleanCsv/2017-09-08.csv',
#  './CleanCsv/2017-09-09.csv',
#  './CleanCsv/2017-09-10.csv',
#  './CleanCsv/2017-09-11.csv',
#  './CleanCsv/2017-09-12.csv',
#  './CleanCsv/2017-09-13.csv',
#  './CleanCsv/2017-09-14.csv',
#  './CleanCsv/2017-09-15.csv',
#  './CleanCsv/2017-09-16.csv',
#  './CleanCsv/2017-09-17.csv',
#  './CleanCsv/2017-09-19.csv',
#  './CleanCsv/2017-09-20.csv',
#  './CleanCsv/2017-09-21.csv',
#  './CleanCsv/2017-09-22.csv',
#  './CleanCsv/2017-09-23.csv',
#  './CleanCsv/2017-09-24.csv',
#  './CleanCsv/2017-09-25.csv',
#  './CleanCsv/2017-09-26.csv',
#  './CleanCsv/2017-09-27.csv',
#  './CleanCsv/2017-09-28.csv',
#  './CleanCsv/2017-09-29.csv',
#  './CleanCsv/2017-09-30.csv',
#  './CleanCsv/2017-10-01.csv',
#  './CleanCsv/2017-10-03.csv',
# ...

# %%
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

# %%
li[78]
# Out:
#      Unnamed: 0       Dates      Power Station  Monitored Cap.(MW)  \
# 0             0  2018-03-19              Delhi              2235.4
# 1             1  2018-03-19            Haryana              2720.0
# 2             2  2018-03-19   Himachal Pradesh              3378.0
# 3             3  2018-03-19  Jammu and Kashmir              1285.0
# 4             4  2018-03-19             Punjab              3826.3
# ..          ...         ...                ...                 ...
# 173         173  2018-03-19            Tripura               169.5
# 174         174  2018-03-19            NEEPCO.              1342.0
# 175         175  2018-03-19               NHPC               105.0
# 176         176  2018-03-19          NTPC Ltd.               500.0
# 177         177  2018-03-19               ONGC               726.6
#
#      Total Cap. Under Maintenace (MW)  Planned Maintanence (MW)  \
# 0                               385.0                       0.0
# ...

# %%
df = pd.concat(li,axis=0)

# %%
excelfile = df.to_excel(f"./test/test.xlsx", encoding='utf-8')
data_xls = pd.read_excel(f'./test/test.xlsx', index_col=None)
data_xls.to_csv(f'./test/concat.csv', encoding='utf-8', index=False)

# %%
for df in li:
    row, column = df.shape
    if row < 176 or column < 12:
        print(df['Dates'][1])
# Out:
# 2017-09-03
# 2017-09-04
# 2017-09-05
# 2017-09-13
# 2017-09-22
# 2017-09-23
# 2017-09-26
# 2017-09-27
# 2018-05-15
# 2018-05-16
# 2018-05-17
# 2018-05-18
# 2018-05-19
# 2018-05-20
# 2018-05-29
# 2018-07-06
# 2018-08-01
# 2018-08-02
# 2018-08-03
# 2018-08-04
# 2018-08-05
# 2018-08-06
# 2018-08-07
# 2018-08-08
# 2018-08-09
# 2018-08-11
# 2018-08-12
# 2018-08-13
# 2018-08-14
# 2018-08-15
# 2018-08-16
# 2018-08-17
# 2018-08-18
# 2018-08-19
# 2018-08-20
# 2018-08-21
# 2018-08-22
# 2018-08-23
# 2018-08-24
# 2018-08-25
# 2018-08-26
# 2018-08-27
# 2018-08-29
# 2019-04-02
# 2019-04-03
# 2019-04-04
# 2019-04-05
# 2019-04-06
# 2019-04-07
# 2019-04-08
# 2019-04-09
# 2019-04-10
# 2019-04-11
# 2019-04-12
# 2019-04-13
# 2019-04-14
# 2019-04-15
# 2019-04-16
# 2019-04-17
# 2019-04-18
# 2019-04-20
# 2019-04-21
# 2019-04-22
# 2019-04-23
# 2019-04-24
# 2019-04-25
# 2019-04-26
# 2019-04-27
# 2019-04-28
# 2019-04-29
# 2019-04-30
# 2019-05-01
# 2019-05-02
# 2019-05-03
# 2019-05-04
# 2019-05-05
# ...

# %%
# Out:
# (176, 12)
